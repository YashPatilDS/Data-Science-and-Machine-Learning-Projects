# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
voice_df = pd.read_csv("/content/drive/MyDrive/Home Practice Datasets/voice.csv")
voice_df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %%
voice_df.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
voice_df.columns
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %%
voice_df.shape
# Out:
# (3168, 21)

# %%
voice_df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.180907     0.057126     0.185621     0.140456     0.224765
# std       0.029918     0.016652     0.036360     0.048680     0.023639
# min       0.039363     0.018363     0.010975     0.000229     0.042946
# 25%       0.163662     0.041954     0.169593     0.111087     0.208747
# 50%       0.184838     0.059155     0.190032     0.140286     0.225684
# 75%       0.199146     0.067020     0.210618     0.175939     0.243660
# max       0.251124     0.115273     0.261224     0.247347     0.273469
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  3168.000000  3168.000000  3168.000000  3168.000000  3168.000000
# mean      0.084309     3.140168    36.568461     0.895127     0.408216
# std       0.042783     4.240529   134.928661     0.044980     0.177521
# ...

# %%
voice_df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
voice_df['label'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#Total Count of Each Categorical Value in column
print("Total no of males :", len(voice_df[voice_df['label'] == 'male']))
print("Total no of females :", len(voice_df[voice_df['label']== 'female']))
# Out:
# Total no of males : 1584
# Total no of females : 1584

# %%
X = voice_df.iloc[:,:-1]
X.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# ...

# %%
y = voice_df.iloc[:,-1]
y.head()
# Out:
# 0    male
# 1    male
# 2    male
# 3    male
# 4    male
# Name: label, dtype: object

# %%
#Converting the target ('label') values into '0'and '1'
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
Scaler.fit(X)
X = Scaler.transform(X)
X
# Out:
# array([[-4.04924806,  0.4273553 , -4.22490077, ..., -1.43142165,
#         -1.41913712, -1.45477229],
#        [-3.84105325,  0.6116695 , -3.99929342, ..., -1.41810716,
#         -1.4058184 , -1.01410294],
#        [-3.46306647,  1.60384791, -4.09585052, ..., -1.42920257,
#         -1.41691733, -1.06534356],
#        ...,
#        [-1.29877326,  2.32272355, -0.05197279, ..., -0.5992661 ,
#         -0.58671739,  0.17588664],
#        [-1.2452018 ,  2.012196  , -0.01772849, ..., -0.41286326,
#         -0.40025537,  1.14916112],
#        [-0.51474626,  2.14765111, -0.07087873, ..., -1.27608595,
#         -1.2637521 ,  1.47567886]])

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 , random_state= 1)

# %%
#Using SVM with default hyperparameter
from sklearn.svm import SVC
from sklearn import metrics
svc =SVC()
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
print("Accuracy Score :", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score : 0.9763406940063092

# %%
#Using Linear Kernel
svc = SVC(kernel='linear')
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
print("Accuracy Score:", metrics.accuracy_score(y_pred,y_test))
# Out:
# Accuracy Score: 0.9779179810725552

# %%
#Using RBF Kernel
svc = SVC(kernel='rbf')
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
print("Accuracy Score:", metrics.accuracy_score(y_pred,y_test))
# Out:
# Accuracy Score: 0.9763406940063092

# %%
#Using Polynomial Kernel
svc = SVC(kernel='poly')
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
print("Accuracy Score:", metrics.accuracy_score(y_pred,y_test))
# Out:
# Accuracy Score: 0.9589905362776026

# %%
#Performing K-fold cross validation with different kernels
from sklearn.model_selection import cross_val_score
svc = SVC(kernel='linear')
scores = cross_val_score(svc, X, y, cv = 10, scoring = 'accuracy')
print("Scores are :", scores)
print("Mean Scores are :", scores.mean())
# Out:
# Scores are : [0.91167192 0.97160883 0.97160883 0.97791798 0.95899054 0.9873817
#  0.99369085 0.97791798 0.95253165 0.99367089]
# Mean Scores are : 0.9696991175178692

# %%
svc = SVC(kernel='rbf')
scores = cross_val_score(svc, X, y, cv = 10, scoring = 'accuracy')
print("Scores are :", scores)
print("Mean Scores are :", scores.mean())
# Out:
# Scores are : [0.93375394 0.95583596 0.96845426 0.96214511 0.96529968 0.99684543
#  0.99053628 0.98422713 0.91455696 0.99367089]
# Mean Scores are : 0.9665325639899376

# %%
svc = SVC(kernel='poly')
scores = cross_val_score(svc, X, y, cv = 10, scoring = 'accuracy')
print("Scores are :", scores)
print("Mean Scores are :", scores.mean())
# Out:
# Scores are : [0.89274448 0.94952681 0.93059937 0.92744479 0.94952681 0.99369085
#  0.98422713 0.96529968 0.87974684 0.9778481 ]
# Mean Scores are : 0.9450654873617378

# %%
C_range = list(range(1,26))
acc_score = []
for c in C_range:
  svc = SVC(kernel='linear', C=c)
  scores = cross_val_score(svc, X, y, cv = 10, scoring = 'accuracy')
  acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.9696991175178692, 0.969068202691371, 0.969068202691371, 0.969068202691371, 0.9693836601046201, 0.9693836601046201, 0.969068202691371, 0.9687527452781215, 0.9684372878648724, 0.9684372878648724, 0.9684372878648724, 0.9684372878648724, 0.9681208321686698, 0.9681208321686698, 0.9681208321686698, 0.9681208321686698, 0.9678043764724673, 0.9678043764724673, 0.9678043764724673, 0.9678043764724673, 0.9681208321686698, 0.968436289581919, 0.968436289581919, 0.9681198338857164, 0.9681198338857164]
